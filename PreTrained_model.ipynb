# %% [markdown]
# <a href="https://colab.research.google.com/github/SriRamK345/Pre-trained-model/blob/main/PreTrained_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

# %%
model = VGG16(weights="imagenet", include_top = True, input_shape=(224,224,3))
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
 # Loading image file

path = "/content/curvv-exterior-right-front-three-quarter.webp"
imagee = image.load_img(path, target_size=(224,224))
x = image.img_to_array(imagee)
x= np.expand_dims(x ,axis=0)
x = preprocess_input(x)

# %%
pred = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
pred
# Out:
# array([[2.41026385e-07, 8.73042083e-08, 7.31787395e-08, 4.93733765e-08,
#         6.56986145e-08, 4.13024253e-07, 1.47107251e-08, 4.91013134e-06,
#         2.56080989e-06, 1.32023501e-06, 8.54750226e-08, 1.41816727e-07,
#         4.25374964e-07, 3.47962015e-08, 7.67956152e-08, 1.39064596e-07,
#         5.74622447e-07, 1.61292363e-07, 1.14173179e-06, 3.63368798e-07,
#         2.61105697e-07, 9.43353200e-07, 9.28278496e-06, 1.73753197e-05,
#         7.67786617e-07, 8.06504943e-07, 6.77794219e-07, 3.81121140e-07,
#         2.82748289e-07, 3.02501093e-07, 8.42927875e-07, 2.98870788e-07,
#         1.39068254e-06, 1.56498354e-05, 1.59340401e-04, 1.73279095e-05,
#         3.71848619e-05, 1.12696707e-05, 1.99303736e-06, 9.46912564e-07,
#         7.13154066e-07, 2.73148748e-06, 1.26548355e-06, 4.40559802e-07,
#         1.62967581e-06, 4.98405507e-06, 3.96734009e-07, 6.44045713e-07,
#         1.09215171e-06, 1.01000876e-06, 6.28669397e-07, 1.76587298e-06,
# ...

# %%
decode_pred = decode_predictions(pred, top=5)[0]
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
for pred in decode_pred:
  print(pred[1],":",pred[2])
# Out:
# beach_wagon : 0.35665005
# car_wheel : 0.16256364
# convertible : 0.08735178
# pickup : 0.08426342
# minivan : 0.08372872

# %% [markdown]
# # X-ray Image Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
